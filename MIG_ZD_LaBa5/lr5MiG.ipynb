# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Чтение CSV файла
csv_file = 'C:\\Users\\user\\M3O234B\\data.csv'
data = pd.read_csv(csv_file)

# Описание пропущенных значений во всех столбцах
missing_values = data.isnull().sum()
print("Пропущенные значения:")
print(missing_values)

# Проверка доли пропущенных значений в каждом столбце
missing_percentage = (data.isnull().sum() / len(data)) * 100
print("\nДоля пропущенных значений в каждом столбце:")
print(missing_percentage)

# Построение графика
plt.figure(figsize=(10, 6))
missing_percentage.plot(kind='bar', color='skyblue')
plt.title('Доля пропущенных значений в каждом столбце')
plt.xlabel('Столбцы')
plt.ylabel('Процент пропусков')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Нахождение медианы столбца 'к'
median_k = data['total_income'].median()

# Заполнение пропущенных значений в столбце 'к' медианным значением
data['total_income'].fillna(median_k, inplace=True)
# Out:
# Пропущенные значения:
# children               0
# days_employed       2174
# dob_years              0
# education              0
# education_id           0
# family_status          0
# family_status_id       0
# gender                 0
# income_type            0
# debt                   0
# total_income        2174
# purpose                0
# dtype: int64
#
# Доля пропущенных значений в каждом столбце:
# children             0.000000
# days_employed       10.099884
# dob_years            0.000000
# education            0.000000
# education_id         0.000000
# family_status        0.000000
# family_status_id     0.000000
# gender               0.000000
# income_type          0.000000
# debt                 0.000000
# total_income        10.099884
# purpose              0.000000
# dtype: float64

# %% [markdown]
# После анализа таблицы и данных в ней были обнаружены пропуски в столбцах "общий трудовой стаж в днях" и "ежемесячный доход".
# Возможные причины появления пропусков:
# Пропуски данных могут возникнуть по различным причинам. Вот несколько возможных
# причин;
# 1. Недоступность информаичин.
# 2. Человеческие
# 3. ных.
# З. Несоответствие форматт пропуски.
# 4. Несовершенство  части данных.
# 5. Отс
# 6. других причин.
# б. Выт к пропускам данных.
# 7. Изменетствуют
# новой структуре их
# потере или повреждению.
# 9.  что может привести к пропускам.
# 10.
#
# Заполнение пропусков медианным значением для количественных переменных является
# предпочтительным решением по следующим причинам:
#
# 1. Сохранение центральной тенденделения.
# 2. Устойчивость кким выбросам
# 3. Подходит для несимметричных ть неоднородными
# 4. Отсутствие влиянияе числовые значения.
# 5реляции между переменными.
# етствующие стратегии их обработки.

# %%
#задание 2. устранение аномалий
# Замена отрицательных значений в первом столбце на 0
data.iloc[:, 0] = data.iloc[:, 0].apply(lambda x: max(x, 0))

############################################################

# Замена отрицательных значений во втором столбце на положительные
data.iloc[:, 1] = data.iloc[:, 1].apply(lambda x: abs(x) if x < 0 else x)

# Замена значений больше 20000 на 20000
data['days_employed'] = data['days_employed'].apply(lambda x: min(x, 20000))

#############################################################

# Удаление строк, где значение в третьем столбце равно 0
data = data[data['dob_years'] != 0]

#############################################################

# Нахождение медианы столбца 'к'
median_k = data['days_employed'].median()

# Заполнение пропущенных значений в столбце 'к' медианным значением
data['days_employed'].fillna(median_k, inplace=True)
data
# Out:
#        children  days_employed  dob_years education  education_id  \
# 0             1    8437.673028         42    высшее             0
# 1             1    4024.803754         36   среднее             1
# 2             0    5623.422610         33   Среднее             1
# 3             3    4124.747207         32   среднее             1
# 4             0   20000.000000         53   среднее             1
# ...         ...            ...        ...       ...           ...
# 21520         1    4529.316663         43   среднее             1
# 21521         0   20000.000000         67   среднее             1
# 21522         1    2113.346888         38   среднее             1
# 21523         3    3112.481705         38   среднее             1
# 21524         2    1984.507589         40   среднее             1
#
#           family_status  family_status_id gender income_type  debt  \
# 0       женат / замужем                 0      F   сотрудник     0
# 1       женат / замужем                 0      F   сотрудник     0
# 2       женат / замужем                 0      M   сотрудник     0
# 3       женат / замужем                 0      M   сотрудник     0
# 4      гражданский брак                 1      F   пенсионер     0
# ...                 ...               ...    ...         ...   ...
# 21520  гражданский брак                 1      F   компаньон     0
# 21521   женат / замужем                 0      F   пенсионер     0
# 21522  гражданский брак                 1      M   сотрудник     1
# 21523   женат / замужем                 0      M   сотрудник     1
# 21524   женат / замужем                 0      F   сотрудник     0
#
#         total_income                       purpose
# 0      253875.639453                 покупка жилья
# 1      112080.014102       приобретение автомобиля
# 2      145885.952297                 покупка жилья
# 3      267628.550329    дополнительное образование
# 4      158616.077870               сыграть свадьбу
# ...              ...                           ...
# 21520  224791.862382             операции с жильем
# 21521  155999.806512          сделка с автомобилем
# 21522   89672.561153                  недвижимость
# 21523  244093.050500  на покупку своего автомобиля
# 21524   82047.418899         на покупку автомобиля
#
# [21424 rows x 12 columns]

# %% [markdown]
# Аномальные данные могут возникнуть по нескольким причинам, включая следующие:
#
# 1. Ошибки ввом.
# 2. Человеческий факий.
# 3. Неправильная обработка даых.

# %%
#задание 3
# Замена вещественного типа данных на целочисленный в столбце total_income
data['total_income'] = data['total_income'].astype(int)
data
# Out:
#        children  days_employed  dob_years education  education_id  \
# 0             1    8437.673028         42    высшее             0
# 1             1    4024.803754         36   среднее             1
# 2             0    5623.422610         33   Среднее             1
# 3             3    4124.747207         32   среднее             1
# 4             0   20000.000000         53   среднее             1
# ...         ...            ...        ...       ...           ...
# 21520         1    4529.316663         43   среднее             1
# 21521         0   20000.000000         67   среднее             1
# 21522         1    2113.346888         38   среднее             1
# 21523         3    3112.481705         38   среднее             1
# 21524         2    1984.507589         40   среднее             1
#
#           family_status  family_status_id gender income_type  debt  \
# 0       женат / замужем                 0      F   сотрудник     0
# 1       женат / замужем                 0      F   сотрудник     0
# 2       женат / замужем                 0      M   сотрудник     0
# 3       женат / замужем                 0      M   сотрудник     0
# 4      гражданский брак                 1      F   пенсионер     0
# ...                 ...               ...    ...         ...   ...
# 21520  гражданский брак                 1      F   компаньон     0
# 21521   женат / замужем                 0      F   пенсионер     0
# 21522  гражданский брак                 1      M   сотрудник     1
# 21523   женат / замужем                 0      M   сотрудник     1
# 21524   женат / замужем                 0      F   сотрудник     0
#
#        total_income                       purpose
# 0            253875                 покупка жилья
# 1            112080       приобретение автомобиля
# 2            145885                 покупка жилья
# 3            267628    дополнительное образование
# 4            158616               сыграть свадьбу
# ...             ...                           ...
# 21520        224791             операции с жильем
# 21521        155999          сделка с автомобилем
# 21522         89672                  недвижимость
# 21523        244093  на покупку своего автомобиля
# 21524         82047         на покупку автомобиля
#
# [21424 rows x 12 columns]

# %%
#задание 4
# Приведение значений четвёртого столбца к нижнему регистру
data.iloc[:, 3] = data.iloc[:, 3].str.lower()

# Удаление повторяющихся строк
data.drop_duplicates(inplace=True)
data
# Out:
#        children  days_employed  dob_years education  education_id  \
# 0             1    8437.673028         42    высшее             0
# 1             1    4024.803754         36   среднее             1
# 2             0    5623.422610         33   среднее             1
# 3             3    4124.747207         32   среднее             1
# 4             0   20000.000000         53   среднее             1
# ...         ...            ...        ...       ...           ...
# 21520         1    4529.316663         43   среднее             1
# 21521         0   20000.000000         67   среднее             1
# 21522         1    2113.346888         38   среднее             1
# 21523         3    3112.481705         38   среднее             1
# 21524         2    1984.507589         40   среднее             1
#
#           family_status  family_status_id gender income_type  debt  \
# 0       женат / замужем                 0      F   сотрудник     0
# 1       женат / замужем                 0      F   сотрудник     0
# 2       женат / замужем                 0      M   сотрудник     0
# 3       женат / замужем                 0      M   сотрудник     0
# 4      гражданский брак                 1      F   пенсионер     0
# ...                 ...               ...    ...         ...   ...
# 21520  гражданский брак                 1      F   компаньон     0
# 21521   женат / замужем                 0      F   пенсионер     0
# 21522  гражданский брак                 1      M   сотрудник     1
# 21523   женат / замужем                 0      M   сотрудник     1
# 21524   женат / замужем                 0      F   сотрудник     0
#
#        total_income                       purpose
# 0            253875                 покупка жилья
# 1            112080       приобретение автомобиля
# 2            145885                 покупка жилья
# 3            267628    дополнительное образование
# 4            158616               сыграть свадьбу
# ...             ...                           ...
# 21520        224791             операции с жильем
# 21521        155999          сделка с автомобилем
# 21522         89672                  недвижимость
# 21523        244093  на покупку своего автомобиля
# 21524         82047         на покупку автомобиля
#
# [21353 rows x 12 columns]

# %% [markdown]
# Для поиска и удаления дубликатов мы использовали метод drop_duplicates().
# Он позволяет удалять строки, в которых значения во всех столбцах полностью совпадают, а именно это нам и надо.
# Приведите возможные причины появления дубликатов
# 1.	Ошибки при вводе данец.
# 2.	Дублирование дажды.
# 3.	Некорректная работа программного обеспеисей.
# 4.	Сбои в работе оборуданных.
# 5.	Неэффективное использование идентифиаписей.
# 6.	Неправильное использование внешниликатов.
# 7.	Использование неверныхформации.
# 8.	Несанкционированформации.

# %%
#задание 5
# Создание "словаря" для education
education_dict = data[['education', 'education_id']].drop_duplicates().reset_index(drop=True)

# Создание "словаря" для family_status
family_status_dict = data[['family_status', 'family_status_id']].drop_duplicates().reset_index(drop=True)

# Удаление столбцов education и family_status из исходного DataFrame
data.drop(['education', 'family_status'], axis=1, inplace=True)

# Сохранение "словарей" в новые файлы (
education_dict.to_csv('education_dict.csv', index=False)
family_status_dict.to_csv('family_status_dict.csv', index=False)

# Вывод получившихся "словарей"
print("Словарь education:")
print(education_dict)
print("\nСловарь family_status:")
print(family_status_dict)
# Out:
# Словарь education:
#              education  education_id
# 0               высшее             0
# 1              среднее             1
# 2  неоконченное высшее             2
# 3            начальное             3
# 4       ученая степень             4
#
# Словарь family_status:
#            family_status  family_status_id
# 0        женат / замужем                 0
# 1       гражданский брак                 1
# 2         вдовец / вдова                 2
# 3              в разводе                 3
# 4  Не женат / не замужем                 4

# %%
#задание 6
# Функция для определения категории на основе значения дохода
def categorize_income(value):
    if value <= 30000:
        return 'E'
    elif 30001 <= value <= 50000:
        return 'D'
    elif 50001 <= value <= 200000:
        return 'C'
    elif 200001 <= value <= 1000000:
        return 'B'
    else:
        return 'A'

# Добавление столбца total_income_category
data['total_income_category'] = data['total_income'].apply(categorize_income)
data
# Out:
#        children  days_employed  dob_years  education_id  family_status_id  \
# 0             1    8437.673028         42             0                 0
# 1             1    4024.803754         36             1                 0
# 2             0    5623.422610         33             1                 0
# 3             3    4124.747207         32             1                 0
# 4             0   20000.000000         53             1                 1
# ...         ...            ...        ...           ...               ...
# 21520         1    4529.316663         43             1                 1
# 21521         0   20000.000000         67             1                 0
# 21522         1    2113.346888         38             1                 1
# 21523         3    3112.481705         38             1                 0
# 21524         2    1984.507589         40             1                 0
#
#       gender income_type  debt  total_income                       purpose  \
# 0          F   сотрудник     0        253875                 покупка жилья
# 1          F   сотрудник     0        112080       приобретение автомобиля
# 2          M   сотрудник     0        145885                 покупка жилья
# 3          M   сотрудник     0        267628    дополнительное образование
# 4          F   пенсионер     0        158616               сыграть свадьбу
# ...      ...         ...   ...           ...                           ...
# 21520      F   компаньон     0        224791             операции с жильем
# 21521      F   пенсионер     0        155999          сделка с автомобилем
# 21522      M   сотрудник     1         89672                  недвижимость
# 21523      M   сотрудник     1        244093  на покупку своего автомобиля
# 21524      F   сотрудник     0         82047         на покупку автомобиля
#
#       total_income_category
# 0                         B
# 1                         C
# 2                         C
# 3                         B
# 4                         C
# ...                     ...
# 21520                     B
# 21521                     C
# 21522                     C
# 21523                     B
# 21524                     C
#
# [21353 rows x 11 columns]

# %%
#задание 7
# Функция для определения категории на основе цели
def categorize_purpose(text):
    if 'авто' in text or 'автомобиль' in text:
        return 'операции с автомобилем'
    elif 'недвиж' in text or 'жиль' in text:
        return 'операции с недвижимостью'
    elif 'свадьб' in text:
        return 'проведение свадьбы'
    elif 'образован' in text or 'учеб' in text:
        return 'получение образования'
    else:
        return 'другое'

# Добавление столбца purpose_category
data['purpose_category'] = data['purpose'].apply(categorize_purpose)

# Сохранение изменений в файл
data.to_csv('file_final__category2.csv', index=False)
data
# Out:
#        children  days_employed  dob_years  education_id  family_status_id  \
# 0             1    8437.673028         42             0                 0
# 1             1    4024.803754         36             1                 0
# 2             0    5623.422610         33             1                 0
# 3             3    4124.747207         32             1                 0
# 4             0   20000.000000         53             1                 1
# ...         ...            ...        ...           ...               ...
# 21520         1    4529.316663         43             1                 1
# 21521         0   20000.000000         67             1                 0
# 21522         1    2113.346888         38             1                 1
# 21523         3    3112.481705         38             1                 0
# 21524         2    1984.507589         40             1                 0
#
#       gender income_type  debt  total_income                       purpose  \
# 0          F   сотрудник     0        253875                 покупка жилья
# 1          F   сотрудник     0        112080       приобретение автомобиля
# 2          M   сотрудник     0        145885                 покупка жилья
# 3          M   сотрудник     0        267628    дополнительное образование
# 4          F   пенсионер     0        158616               сыграть свадьбу
# ...      ...         ...   ...           ...                           ...
# 21520      F   компаньон     0        224791             операции с жильем
# 21521      F   пенсионер     0        155999          сделка с автомобилем
# 21522      M   сотрудник     1         89672                  недвижимость
# 21523      M   сотрудник     1        244093  на покупку своего автомобиля
# 21524      F   сотрудник     0         82047         на покупку автомобиля
#
#       total_income_category          purpose_category
# 0                         B  операции с недвижимостью
# 1                         C    операции с автомобилем
# 2                         C  операции с недвижимостью
# 3                         B     получение образования
# 4                         C        проведение свадьбы
# ...                     ...                       ...
# 21520                     B  операции с недвижимостью
# 21521                     C    операции с автомобилем
# 21522                     C  операции с недвижимостью
# 21523                     B    операции с автомобилем
# 21524                     C    операции с автомобилем
#
# [21353 rows x 12 columns]

# %%
import pandas as pd
# Чтение файла
file_name = 'file_final__category2.csv'
data = pd.read_csv(file_name)
# Группировка данных по уникальным значениям 'children' и подсчет суммы 'debt' для каждого значения 'children'
grouped_data = data.groupby('children')['debt'].sum()
# Подсчет количества значений 'debt' для каждого значения 'children'
value_counts= data['children'].value_counts()
# Объединение результатов в один DataFrame
result = pd.concat([value_counts, grouped_data], axis=1)
result.columns = ['Count', 'Sum of Debt']
# Добавление столбца 'Statistic' с результатом деления количества строк на сумму 'debt'
result['Statistic'] = result['Count'] / result['Sum of Debt']
# Вывод результата
print(result.to_string())
# Out:
#           Count  Sum of Debt  Statistic
# children
# 0         14069         1059  13.285175
# 1          4792          441  10.866213
# 2          2039          194  10.510309
# 3           328           27  12.148148
# 20           75            8   9.375000
# 4            41            4  10.250000
# 5             9            0        inf

# %% [markdown]
# Есть ли зависимость между количеством детей и возвратом кредита в срок?
#  У кого нет детей, у того больше задолжностей

# %%
#Чтение файла
file_name = 'file_final__category2.csv'
data = pd.read_csv(file_name)
# Группировка данных по уникальным значениям 'family_status_id' и подсчет суммы 'debt' для каждого значения 'family_status_id'
grouped_data = data.groupby('family_status_id')['debt'].sum()
# Подсчет количества значений 'debt' для каждого значения 'family_status_id'
value_counts = data['family_status_id'].value_counts()
# Объединение результатов в один DataFrame
result = pd.concat([value_counts, grouped_data], axis=1)
result.columns = ['Count', 'Sum of Debt']
# Добавление столбца 'Statistic' с результатом деления количества строк на сумму 'debt'
result['Statistic'] = result['Count'] / result['Sum of Debt']
# Вывод результата
print(result)
# Out:
#                   Count  Sum of Debt  Statistic
# family_status_id
# 0                 12290          927  13.257821
# 1                  4130          386  10.699482
# 4                  2794          273  10.234432
# 3                  1185           85  13.941176
# 2                   954           62  15.387097

# %% [markdown]
# Есть ли зависимость между семейным положением и возвратом кредита в срок?
# Вдовцы и вдовы наиболее склонны к задолжностям

# %%
# Чтение файла
file_name = 'file_final__category2.csv'
data = pd.read_csv(file_name)
# Группировка данных по уникальным значениям 'total_income_category' и подсчет суммы 'debt' для каждого значения 'total_income_category'
grouped_data = data.groupby('total_income_category')['debt'].sum()
# Подсчет количества значений 'debt' для каждого значения 'total_income_category'
value_counts = data['total_income_category'].value_counts()
# Объединение результатов в один DataFrame
result = pd.concat([value_counts, grouped_data], axis=1)
result.columns = ['Count', 'Sum of Debt']
# Добавление столбца 'Statistic' с результатом деления количества строк на сумму 'debt'
result['Statistic'] = result['Count'] / result['Sum of Debt']
# Вывод результата
print(result)
# Out:
#                        Count  Sum of Debt  Statistic
# total_income_category
# C                      15943         1353  11.783444
# B                       5015          355  14.126761
# D                        348           21  16.571429
# A                         25            2  12.500000
# E                         22            2  11.000000

# %% [markdown]
# Есть ли зависимость между уровнем дохода и возвратом кредита в срок?
# Люди с уровнем дохода категории D больше склонны к задолжностям

# %%
# Чтение файла
file_name = 'file_final__category2.csv'
data = pd.read_csv(file_name)

# Группировка данных по уникальным значениям 'purpose_category' и подсчет суммы 'debt' для каждого значения 'purpose_category'
grouped_data = data.groupby('purpose_category')['debt'].sum()

# Подсчет количества значений 'debt' для каждого значения 'purpose_category'
value_counts = data['purpose_category'].value_counts()

# Объединение результатов в один DataFrame
result = pd.concat([value_counts, grouped_data], axis=1)
result.columns = ['Count', 'Sum of Debt']

# Добавление столбца 'Statistic' с результатом деления количества строк на сумму 'debt'
result['Statistic'] = result['Count'] / result['Sum of Debt']

# Вывод результата
print(result)
# Out:
#                           Count  Sum of Debt  Statistic
# purpose_category
# операции с недвижимостью  10764          779  13.817715
# операции с автомобилем     4284          400  10.710000
# получение образования      3995          370  10.797297
# проведение свадьбы         2310          184  12.554348

# %% [markdown]
# Как разные цели кредита влияют на его возврат в срок?
# Цель кредита "операции с недвижимостью" наиболее распростроненна в просрочке срока оплаты

# %% [markdown]
# Вывод:
# На возврат кредита влияет множество факторов.
